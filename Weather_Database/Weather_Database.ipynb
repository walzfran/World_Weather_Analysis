# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# print(url)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | tuktoyaktuk
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | yellowknife
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | thompson
# Processing Record 8 of Set 1 | olinda
# Processing Record 9 of Set 1 | clyde river
# Processing Record 10 of Set 1 | karratha
# Processing Record 11 of Set 1 | port alfred
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | ust-maya
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | nikolskoye
# Processing Record 16 of Set 1 | noyon
# Processing Record 17 of Set 1 | san quintin
# Processing Record 18 of Set 1 | ilulissat
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 1 | iqaluit
# Processing Record 22 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 1 | nara
# Processing Record 24 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 1 | fort-shevchenko
# Processing Record 26 of Set 1 | hami
# Processing Record 27 of Set 1 | chuy
# Processing Record 28 of Set 1 | provideniya
# Processing Record 29 of Set 1 | saint-philippe
# Processing Record 30 of Set 1 | karpathos
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 1 | hasaki
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | alexandria
# Processing Record 36 of Set 1 | sivas
# Processing Record 37 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 1 | puerto triunfo
# Processing Record 39 of Set 1 | haines junction
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | puerto leguizamo
# Processing Record 42 of Set 1 | meulaboh
# Processing Record 43 of Set 1 | atuona
# Processing Record 44 of Set 1 | noyabrsk
# Processing Record 45 of Set 1 | pemangkat
# Processing Record 46 of Set 1 | shizunai
# Processing Record 47 of Set 1 | salalah
# Processing Record 48 of Set 1 | kupang
# Processing Record 49 of Set 1 | nanortalik
# Processing Record 50 of Set 1 | srednekolymsk
# Processing Record 1 of Set 2 | bathsheba
# Processing Record 2 of Set 2 | banda aceh
# Processing Record 3 of Set 2 | talcahuano
# Processing Record 4 of Set 2 | sorland
# Processing Record 5 of Set 2 | rikitea
# Processing Record 6 of Set 2 | fukue
# Processing Record 7 of Set 2 | ribeira grande
# Processing Record 8 of Set 2 | nome
# Processing Record 9 of Set 2 | mehamn
# Processing Record 10 of Set 2 | pingzhuang
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | coracora
# Processing Record 13 of Set 2 | carnarvon
# Processing Record 14 of Set 2 | miri
# Processing Record 15 of Set 2 | punta arenas
# Processing Record 16 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 2 | cape town
# Processing Record 18 of Set 2 | cherskiy
# Processing Record 19 of Set 2 | dalbandin
# Processing Record 20 of Set 2 | kysyl-syr
# Processing Record 21 of Set 2 | rehoboth
# Processing Record 22 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 2 | luangwa
# Processing Record 24 of Set 2 | marawi
# Processing Record 25 of Set 2 | siderno
# Processing Record 26 of Set 2 | tasiilaq
# Processing Record 27 of Set 2 | leningradskiy
# Processing Record 28 of Set 2 | baherden
# Processing Record 29 of Set 2 | hermanus
# Processing Record 30 of Set 2 | sioux lookout
# Processing Record 31 of Set 2 | ust-nera
# Processing Record 32 of Set 2 | georgetown
# Processing Record 33 of Set 2 | kahului
# Processing Record 34 of Set 2 | katsuura
# Processing Record 35 of Set 2 | new norfolk
# Processing Record 36 of Set 2 | flin flon
# Processing Record 37 of Set 2 | rio verde de mato grosso
# Processing Record 38 of Set 2 | victoria
# Processing Record 39 of Set 2 | port hedland
# Processing Record 40 of Set 2 | aksu
# Processing Record 41 of Set 2 | dikson
# Processing Record 42 of Set 2 | sierpc
# Processing Record 43 of Set 2 | linjiang
# Processing Record 44 of Set 2 | sagae
# Processing Record 45 of Set 2 | ketchikan
# Processing Record 46 of Set 2 | geraldton
# Processing Record 47 of Set 2 | coquimbo
# Processing Record 48 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set 2 | kodiak
# Processing Record 50 of Set 2 | broome
# Processing Record 1 of Set 3 | avera
# Processing Record 2 of Set 3 | baykit
# Processing Record 3 of Set 3 | blairmore
# Processing Record 4 of Set 3 | castro
# Processing Record 5 of Set 3 | vestmannaeyjar
# Processing Record 6 of Set 3 | playas
# Processing Record 7 of Set 3 | lebu
# Processing Record 8 of Set 3 | faya
# Processing Record 9 of Set 3 | qaanaaq
# Processing Record 10 of Set 3 | benavente
# Processing Record 11 of Set 3 | arraial do cabo
# Processing Record 12 of Set 3 | butaritari
# Processing Record 13 of Set 3 | bambous virieux
# Processing Record 14 of Set 3 | torbay
# Processing Record 15 of Set 3 | mar del plata
# Processing Record 16 of Set 3 | owando
# Processing Record 17 of Set 3 | chagoda
# Processing Record 18 of Set 3 | kungurtug
# Processing Record 19 of Set 3 | tongliao
# Processing Record 20 of Set 3 | north bend
# Processing Record 21 of Set 3 | wundanyi
# Processing Record 22 of Set 3 | wuwei
# Processing Record 23 of Set 3 | aksarka
# Processing Record 24 of Set 3 | nemuro
# Processing Record 25 of Set 3 | asilah
# Processing Record 26 of Set 3 | skagastrond
# City not found. Skipping...
# Processing Record 27 of Set 3 | klaksvik
# Processing Record 28 of Set 3 | marsabit
# Processing Record 29 of Set 3 | sibu
# Processing Record 30 of Set 3 | port-cartier
# Processing Record 31 of Set 3 | hammerfest
# Processing Record 32 of Set 3 | port elizabeth
# Processing Record 33 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 34 of Set 3 | hithadhoo
# Processing Record 35 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 3 | cabo san lucas
# Processing Record 37 of Set 3 | houma
# Processing Record 38 of Set 3 | borba
# Processing Record 39 of Set 3 | mahebourg
# Processing Record 40 of Set 3 | ewo
# Processing Record 41 of Set 3 | college
# Processing Record 42 of Set 3 | pevek
# Processing Record 43 of Set 3 | cidreira
# Processing Record 44 of Set 3 | leh
# Processing Record 45 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 46 of Set 3 | mildura
# Processing Record 47 of Set 3 | yarada
# Processing Record 48 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 49 of Set 3 | yar-sale
# Processing Record 50 of Set 3 | samarai
# Processing Record 1 of Set 4 | khatanga
# Processing Record 2 of Set 4 | bredasdorp
# Processing Record 3 of Set 4 | ban dung
# Processing Record 4 of Set 4 | anadyr
# Processing Record 5 of Set 4 | siauliai
# Processing Record 6 of Set 4 | tiznit
# Processing Record 7 of Set 4 | acapulco
# Processing Record 8 of Set 4 | makasar
# Processing Record 9 of Set 4 | chokurdakh
# Processing Record 10 of Set 4 | liverpool
# Processing Record 11 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 4 | bengkulu
# Processing Record 13 of Set 4 | redmond
# Processing Record 14 of Set 4 | andenes
# Processing Record 15 of Set 4 | kavieng
# Processing Record 16 of Set 4 | ann arbor
# Processing Record 17 of Set 4 | creemore
# Processing Record 18 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 4 | avarua
# Processing Record 20 of Set 4 | marsa matruh
# Processing Record 21 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 22 of Set 4 | ambilobe
# Processing Record 23 of Set 4 | maragogi
# Processing Record 24 of Set 4 | kruisfontein
# Processing Record 25 of Set 4 | lavrentiya
# Processing Record 26 of Set 4 | isangel
# Processing Record 27 of Set 4 | port augusta
# Processing Record 28 of Set 4 | severo-kurilsk
# Processing Record 29 of Set 4 | maceio
# Processing Record 30 of Set 4 | san patricio
# Processing Record 31 of Set 4 | catalao
# Processing Record 32 of Set 4 | roald
# Processing Record 33 of Set 4 | itarema
# Processing Record 34 of Set 4 | pascagoula
# Processing Record 35 of Set 4 | labuhan
# Processing Record 36 of Set 4 | kaeo
# Processing Record 37 of Set 4 | merritt island
# Processing Record 38 of Set 4 | amor
# Processing Record 39 of Set 4 | saskylakh
# Processing Record 40 of Set 4 | lompoc
# Processing Record 41 of Set 4 | mandalgovi
# Processing Record 42 of Set 4 | harper
# Processing Record 43 of Set 4 | mayo
# Processing Record 44 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 4 | trairi
# Processing Record 46 of Set 4 | bethel
# Processing Record 47 of Set 4 | tiksi
# Processing Record 48 of Set 4 | eureka
# Processing Record 49 of Set 4 | sola
# Processing Record 50 of Set 4 | kendari
# Processing Record 1 of Set 5 | ixtapa
# Processing Record 2 of Set 5 | acari
# Processing Record 3 of Set 5 | valley city
# Processing Record 4 of Set 5 | port macquarie
# Processing Record 5 of Set 5 | namibe
# Processing Record 6 of Set 5 | mandera
# Processing Record 7 of Set 5 | codrington
# Processing Record 8 of Set 5 | mount pleasant
# Processing Record 9 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 5 | henties bay
# Processing Record 11 of Set 5 | eyemouth
# Processing Record 12 of Set 5 | akdepe
# Processing Record 13 of Set 5 | kyra
# Processing Record 14 of Set 5 | sakakah
# Processing Record 15 of Set 5 | hofn
# Processing Record 16 of Set 5 | palmer
# Processing Record 17 of Set 5 | bourail
# Processing Record 18 of Set 5 | grindavik
# Processing Record 19 of Set 5 | bilibino
# Processing Record 20 of Set 5 | brae
# Processing Record 21 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 5 | banjar
# Processing Record 23 of Set 5 | pemberton
# Processing Record 24 of Set 5 | maniitsoq
# Processing Record 25 of Set 5 | tuatapere
# Processing Record 26 of Set 5 | imbituba
# Processing Record 27 of Set 5 | husavik
# Processing Record 28 of Set 5 | luba
# Processing Record 29 of Set 5 | gomel
# Processing Record 30 of Set 5 | shypyntsi
# Processing Record 31 of Set 5 | pitimbu
# Processing Record 32 of Set 5 | anloga
# Processing Record 33 of Set 5 | norman wells
# Processing Record 34 of Set 5 | barrow
# Processing Record 35 of Set 5 | saint anthony
# Processing Record 36 of Set 5 | shahrud
# Processing Record 37 of Set 5 | hobbs
# Processing Record 38 of Set 5 | ponta do sol
# Processing Record 39 of Set 5 | waddan
# Processing Record 40 of Set 5 | sitka
# Processing Record 41 of Set 5 | san cristobal
# Processing Record 42 of Set 5 | riyadh
# Processing Record 43 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 5 | vardo
# Processing Record 45 of Set 5 | kununurra
# Processing Record 46 of Set 5 | tarko-sale
# Processing Record 47 of Set 5 | vikulovo
# Processing Record 48 of Set 5 | ambulu
# Processing Record 49 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 5 | nizhniy bestyakh
# Processing Record 1 of Set 6 | casas grandes
# Processing Record 2 of Set 6 | westport
# Processing Record 3 of Set 6 | bella union
# Processing Record 4 of Set 6 | alice springs
# Processing Record 5 of Set 6 | sao filipe
# Processing Record 6 of Set 6 | jasper
# Processing Record 7 of Set 6 | qasigiannguit
# Processing Record 8 of Set 6 | chunskiy
# Processing Record 9 of Set 6 | puerto narino
# Processing Record 10 of Set 6 | constitucion
# Processing Record 11 of Set 6 | lengshuitan
# Processing Record 12 of Set 6 | zonguldak
# Processing Record 13 of Set 6 | khani
# Processing Record 14 of Set 6 | neyshabur
# Processing Record 15 of Set 6 | ippy
# Processing Record 16 of Set 6 | bosobolo
# Processing Record 17 of Set 6 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 18 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 6 | east london
# Processing Record 20 of Set 6 | north platte
# Processing Record 21 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 22 of Set 6 | sohbatpur
# Processing Record 23 of Set 6 | beloha
# Processing Record 24 of Set 6 | baoro
# Processing Record 25 of Set 6 | la romana
# Processing Record 26 of Set 6 | nagato
# Processing Record 27 of Set 6 | marion
# Processing Record 28 of Set 6 | sahuaripa
# Processing Record 29 of Set 6 | ambon
# Processing Record 30 of Set 6 | pimentel
# Processing Record 31 of Set 6 | linguere
# Processing Record 32 of Set 6 | mullaitivu
# City not found. Skipping...
# Processing Record 33 of Set 6 | asfi
# Processing Record 34 of Set 6 | emerald
# Processing Record 35 of Set 6 | velikooktyabrskiy
# Processing Record 36 of Set 6 | manadhoo
# Processing Record 37 of Set 6 | airai
# Processing Record 38 of Set 6 | narsaq
# Processing Record 39 of Set 6 | lohja
# Processing Record 40 of Set 6 | upernavik
# Processing Record 41 of Set 6 | prince rupert
# Processing Record 42 of Set 6 | diamantino
# Processing Record 43 of Set 6 | centralia
# Processing Record 44 of Set 6 | luena
# Processing Record 45 of Set 6 | ca mau
# Processing Record 46 of Set 6 | do rud
# City not found. Skipping...
# Processing Record 47 of Set 6 | haapiti
# Processing Record 48 of Set 6 | kebomas
# Processing Record 49 of Set 6 | hovd
# Processing Record 50 of Set 6 | puerto escondido
# Processing Record 1 of Set 7 | bandarbeyla
# Processing Record 2 of Set 7 | yerbogachen
# Processing Record 3 of Set 7 | alamogordo
# Processing Record 4 of Set 7 | porto novo
# Processing Record 5 of Set 7 | tura
# Processing Record 6 of Set 7 | phuntsholing
# Processing Record 7 of Set 7 | saldanha
# Processing Record 8 of Set 7 | tsienyane
# City not found. Skipping...
# Processing Record 9 of Set 7 | aklavik
# Processing Record 10 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 11 of Set 7 | neryungri
# Processing Record 12 of Set 7 | pisco
# Processing Record 13 of Set 7 | mulhouse
# Processing Record 14 of Set 7 | bogovina
# Processing Record 15 of Set 7 | port blair
# Processing Record 16 of Set 7 | saquarema
# Processing Record 17 of Set 7 | wanaka
# Processing Record 18 of Set 7 | caravelas
# Processing Record 19 of Set 7 | axim
# Processing Record 20 of Set 7 | pacific grove
# Processing Record 21 of Set 7 | mafinga
# Processing Record 22 of Set 7 | hambantota
# Processing Record 23 of Set 7 | kirakira
# Processing Record 24 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 25 of Set 7 | havre
# Processing Record 26 of Set 7 | sechura
# Processing Record 27 of Set 7 | tam ky
# Processing Record 28 of Set 7 | ibotirama
# Processing Record 29 of Set 7 | aguililla
# Processing Record 30 of Set 7 | krasnaya gorbatka
# Processing Record 31 of Set 7 | vila velha
# Processing Record 32 of Set 7 | longyearbyen
# Processing Record 33 of Set 7 | methven
# Processing Record 34 of Set 7 | gogrial
# Processing Record 35 of Set 7 | iralaya
# Processing Record 36 of Set 7 | angoram
# Processing Record 37 of Set 7 | altay
# Processing Record 38 of Set 7 | eyl
# Processing Record 39 of Set 7 | ancud
# Processing Record 40 of Set 7 | vung tau
# Processing Record 41 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 7 | guerrero negro
# Processing Record 43 of Set 7 | faanui
# Processing Record 44 of Set 7 | changji
# Processing Record 45 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 7 | saint george
# Processing Record 47 of Set 7 | dudinka
# Processing Record 48 of Set 7 | sarandi
# Processing Record 49 of Set 7 | balimo
# City not found. Skipping...
# Processing Record 50 of Set 7 | fort nelson
# Processing Record 1 of Set 8 | bocas del toro
# Processing Record 2 of Set 8 | hvide sande
# Processing Record 3 of Set 8 | kieta
# Processing Record 4 of Set 8 | makakilo city
# Processing Record 5 of Set 8 | zhuhai
# Processing Record 6 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 8 | paamiut
# Processing Record 8 of Set 8 | dangriga
# Processing Record 9 of Set 8 | kon tum
# Processing Record 10 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 8 | nuuk
# Processing Record 12 of Set 8 | sabya
# Processing Record 13 of Set 8 | vallenar
# Processing Record 14 of Set 8 | larsnes
# Processing Record 15 of Set 8 | bodden town
# Processing Record 16 of Set 8 | acarau
# Processing Record 17 of Set 8 | saint-augustin
# Processing Record 18 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 8 | olafsvik
# Processing Record 20 of Set 8 | praia da vitoria
# Processing Record 21 of Set 8 | sur
# Processing Record 22 of Set 8 | gold coast
# Processing Record 23 of Set 8 | kwidzyn
# Processing Record 24 of Set 8 | wanning
# Processing Record 25 of Set 8 | nanhai
# Processing Record 26 of Set 8 | ahuimanu
# Processing Record 27 of Set 8 | amos
# Processing Record 28 of Set 8 | dronninglund
# Processing Record 29 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 8 | kingman
# Processing Record 31 of Set 8 | deputatskiy
# Processing Record 32 of Set 8 | brownsville
# Processing Record 33 of Set 8 | yelizovo
# Processing Record 34 of Set 8 | waipawa
# Processing Record 35 of Set 8 | jalingo
# Processing Record 36 of Set 8 | trinidad
# Processing Record 37 of Set 8 | mantua
# Processing Record 38 of Set 8 | quelimane
# Processing Record 39 of Set 8 | log
# Processing Record 40 of Set 8 | alyangula
# Processing Record 41 of Set 8 | cockburn town
# Processing Record 42 of Set 8 | muktsar
# Processing Record 43 of Set 8 | touros
# Processing Record 44 of Set 8 | dingle
# Processing Record 45 of Set 8 | inhambane
# Processing Record 46 of Set 8 | grand gaube
# Processing Record 47 of Set 8 | bontang
# Processing Record 48 of Set 8 | ashoknagar
# Processing Record 49 of Set 8 | wittelsheim
# Processing Record 50 of Set 8 | bolobo
# Processing Record 1 of Set 9 | dzaoudzi
# Processing Record 2 of Set 9 | vostok
# Processing Record 3 of Set 9 | sao lourenco da serra
# Processing Record 4 of Set 9 | honningsvag
# Processing Record 5 of Set 9 | egvekinot
# Processing Record 6 of Set 9 | huarmey
# Processing Record 7 of Set 9 | kaitangata
# Processing Record 8 of Set 9 | kenai
# Processing Record 9 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 10 of Set 9 | inta
# Processing Record 11 of Set 9 | fairbanks
# Processing Record 12 of Set 9 | floro
# Processing Record 13 of Set 9 | esperance
# Processing Record 14 of Set 9 | zemio
# Processing Record 15 of Set 9 | lata
# Processing Record 16 of Set 9 | kambove
# Processing Record 17 of Set 9 | mason city
# Processing Record 18 of Set 9 | pangnirtung
# Processing Record 19 of Set 9 | marshall
# Processing Record 20 of Set 9 | lorengau
# Processing Record 21 of Set 9 | la ronge
# Processing Record 22 of Set 9 | swan hill
# Processing Record 23 of Set 9 | vanavara
# Processing Record 24 of Set 9 | tazmalt
# Processing Record 25 of Set 9 | esso
# Processing Record 26 of Set 9 | yumen
# Processing Record 27 of Set 9 | tessalit
# Processing Record 28 of Set 9 | totana
# Processing Record 29 of Set 9 | jacareacanga
# Processing Record 30 of Set 9 | bosaso
# Processing Record 31 of Set 9 | jalu
# Processing Record 32 of Set 9 | agadez
# Processing Record 33 of Set 9 | gizo
# Processing Record 34 of Set 9 | peskovka
# Processing Record 35 of Set 9 | rumenka
# Processing Record 36 of Set 9 | murgab
# Processing Record 37 of Set 9 | champerico
# Processing Record 38 of Set 9 | samandag
# Processing Record 39 of Set 9 | lashio
# Processing Record 40 of Set 9 | walvis bay
# Processing Record 41 of Set 9 | rocha
# Processing Record 42 of Set 9 | tabou
# Processing Record 43 of Set 9 | mbini
# Processing Record 44 of Set 9 | reitz
# Processing Record 45 of Set 9 | ponta delgada
# Processing Record 46 of Set 9 | neuquen
# Processing Record 47 of Set 9 | nhulunbuy
# Processing Record 48 of Set 9 | sibolga
# Processing Record 49 of Set 9 | jumla
# Processing Record 50 of Set 9 | lalmohan
# Processing Record 1 of Set 10 | ryde
# Processing Record 2 of Set 10 | manta
# Processing Record 3 of Set 10 | fria
# Processing Record 4 of Set 10 | havelock
# Processing Record 5 of Set 10 | sumbe
# Processing Record 6 of Set 10 | silvania
# Processing Record 7 of Set 10 | kulhudhuffushi
# Processing Record 8 of Set 10 | bambanglipuro
# Processing Record 9 of Set 10 | hays
# Processing Record 10 of Set 10 | baraya
# Processing Record 11 of Set 10 | goderich
# Processing Record 12 of Set 10 | atambua
# Processing Record 13 of Set 10 | tekkali
# Processing Record 14 of Set 10 | guabito
# Processing Record 15 of Set 10 | aripuana
# Processing Record 16 of Set 10 | neiafu
# Processing Record 17 of Set 10 | dunedin
# Processing Record 18 of Set 10 | bageshwar
# Processing Record 19 of Set 10 | fortuna
# Processing Record 20 of Set 10 | souillac
# Processing Record 21 of Set 10 | punta de piedra
# Processing Record 22 of Set 10 | zeya
# Processing Record 23 of Set 10 | khania
# City not found. Skipping...
# Processing Record 24 of Set 10 | loknya
# Processing Record 25 of Set 10 | kalmunai
# Processing Record 26 of Set 10 | kathu
# Processing Record 27 of Set 10 | sawtell
# Processing Record 28 of Set 10 | luderitz
# Processing Record 29 of Set 10 | atemar
# Processing Record 30 of Set 10 | atikokan
# Processing Record 31 of Set 10 | lakes entrance
# Processing Record 32 of Set 10 | san juan bautista
# Processing Record 33 of Set 10 | serafimovskiy
# Processing Record 34 of Set 10 | larreynaga
# Processing Record 35 of Set 10 | oranjestad
# Processing Record 36 of Set 10 | rincon
# Processing Record 37 of Set 10 | breyten
# Processing Record 38 of Set 10 | vieques
# Processing Record 39 of Set 10 | kristinehamn
# Processing Record 40 of Set 10 | poum
# Processing Record 41 of Set 10 | naze
# Processing Record 42 of Set 10 | talnakh
# Processing Record 43 of Set 10 | aykhal
# Processing Record 44 of Set 10 | tazovskiy
# Processing Record 45 of Set 10 | chaplynka
# Processing Record 46 of Set 10 | troitsko-pechorsk
# Processing Record 47 of Set 10 | el sauzal
# Processing Record 48 of Set 10 | padang
# Processing Record 49 of Set 10 | lagoa
# Processing Record 50 of Set 10 | san vicente de canete
# Processing Record 1 of Set 11 | buala
# Processing Record 2 of Set 11 | kangaatsiaq
# Processing Record 3 of Set 11 | la palma
# Processing Record 4 of Set 11 | mitsamiouli
# Processing Record 5 of Set 11 | campos altos
# Processing Record 6 of Set 11 | shelopugino
# Processing Record 7 of Set 11 | smithers
# Processing Record 8 of Set 11 | newton
# Processing Record 9 of Set 11 | ekhabi
# Processing Record 10 of Set 11 | burica
# City not found. Skipping...
# Processing Record 11 of Set 11 | sobolevo
# Processing Record 12 of Set 11 | mizan teferi
# Processing Record 13 of Set 11 | usinsk
# Processing Record 14 of Set 11 | mezen
# Processing Record 15 of Set 11 | luwuk
# Processing Record 16 of Set 11 | likhoslavl
# Processing Record 17 of Set 11 | okhotsk
# Processing Record 18 of Set 11 | skibbereen
# Processing Record 19 of Set 11 | mount isa
# Processing Record 20 of Set 11 | bud
# Processing Record 21 of Set 11 | pervoye maya
# Processing Record 22 of Set 11 | kawalu
# Processing Record 23 of Set 11 | hobyo
# Processing Record 24 of Set 11 | fuerte olimpo
# Processing Record 25 of Set 11 | dothan
# Processing Record 26 of Set 11 | luoyang
# Processing Record 27 of Set 11 | erdenet
# Processing Record 28 of Set 11 | vila franca do campo
# Processing Record 29 of Set 11 | mogadishu
# Processing Record 30 of Set 11 | waw
# Processing Record 31 of Set 11 | kismayo
# Processing Record 32 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 33 of Set 11 | port hardy
# Processing Record 34 of Set 11 | manavalakurichi
# Processing Record 35 of Set 11 | jega
# Processing Record 36 of Set 11 | cayenne
# Processing Record 37 of Set 11 | velikie luki
# City not found. Skipping...
# Processing Record 38 of Set 11 | tocopilla
# Processing Record 39 of Set 11 | taoudenni
# Processing Record 40 of Set 11 | china
# Processing Record 41 of Set 11 | vilhena
# Processing Record 42 of Set 11 | mersing
# Processing Record 43 of Set 11 | port-gentil
# Processing Record 44 of Set 11 | artigas
# Processing Record 45 of Set 11 | lasa
# Processing Record 46 of Set 11 | northam
# Processing Record 47 of Set 11 | jenjarom
# Processing Record 48 of Set 11 | puerto maldonado
# Processing Record 49 of Set 11 | teknaf
# Processing Record 50 of Set 11 | ystad
# Processing Record 1 of Set 12 | nipawin
# Processing Record 2 of Set 12 | abha
# Processing Record 3 of Set 12 | dezhou
# Processing Record 4 of Set 12 | tucupita
# Processing Record 5 of Set 12 | sligo
# Processing Record 6 of Set 12 | zhumadian
# Processing Record 7 of Set 12 | uyemskiy
# Processing Record 8 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 9 of Set 12 | khorinsk
# Processing Record 10 of Set 12 | innisfail
# Processing Record 11 of Set 12 | guajara-mirim
# City not found. Skipping...
# Processing Record 12 of Set 12 | valparaiso
# Processing Record 13 of Set 12 | tibati
# Processing Record 14 of Set 12 | burns lake
# Processing Record 15 of Set 12 | pudozh
# Processing Record 16 of Set 12 | mecca
# Processing Record 17 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 18 of Set 12 | general pico
# Processing Record 19 of Set 12 | mae tha
# Processing Record 20 of Set 12 | araouane
# Processing Record 21 of Set 12 | yaan
# Processing Record 22 of Set 12 | weligama
# Processing Record 23 of Set 12 | asau
# Processing Record 24 of Set 12 | mangan
# Processing Record 25 of Set 12 | ust-tsilma
# Processing Record 26 of Set 12 | bara
# Processing Record 27 of Set 12 | rabo de peixe
# Processing Record 28 of Set 12 | sambava
# Processing Record 29 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 12 | raga
# Processing Record 31 of Set 12 | tendukheda
# Processing Record 32 of Set 12 | ulladulla
# Processing Record 33 of Set 12 | crab hill
# City not found. Skipping...
# Processing Record 34 of Set 12 | blagoyevo
# Processing Record 35 of Set 12 | dolores hidalgo
# Processing Record 36 of Set 12 | tucuman
# Processing Record 37 of Set 12 | dicabisagan
# Processing Record 38 of Set 12 | amga
# Processing Record 39 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 40 of Set 12 | ingham
# Processing Record 41 of Set 12 | mettur
# Processing Record 42 of Set 12 | georgiyevka
# Processing Record 43 of Set 12 | tamandare
# Processing Record 44 of Set 12 | sao joao da barra
# Processing Record 45 of Set 12 | rovigo
# Processing Record 46 of Set 12 | umm lajj
# Processing Record 47 of Set 12 | morondava
# Processing Record 48 of Set 12 | tabarqah
# City not found. Skipping...
# Processing Record 49 of Set 12 | akyab
# Processing Record 50 of Set 12 | havre-saint-pierre
# Processing Record 1 of Set 13 | awjilah
# Processing Record 2 of Set 13 | pangody
# Processing Record 3 of Set 13 | hvammstangi
# City not found. Skipping...
# Processing Record 4 of Set 13 | springfield
# Processing Record 5 of Set 13 | kuusamo
# Processing Record 6 of Set 13 | ponferrada
# Processing Record 7 of Set 13 | iquique
# Processing Record 8 of Set 13 | cairns
# Processing Record 9 of Set 13 | lishui
# Processing Record 10 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 13 | alofi
# Processing Record 12 of Set 13 | quatre cocos
# Processing Record 13 of Set 13 | halifax
# Processing Record 14 of Set 13 | wallaceburg
# Processing Record 15 of Set 13 | morro bay
# Processing Record 16 of Set 13 | veraval
# Processing Record 17 of Set 13 | de aar
# Processing Record 18 of Set 13 | los llanos de aridane
# Processing Record 19 of Set 13 | ahipara
# Processing Record 20 of Set 13 | bursol
# City not found. Skipping...
# Processing Record 21 of Set 13 | abalak
# Processing Record 22 of Set 13 | namatanai
# Processing Record 23 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 24 of Set 13 | tezu
# Processing Record 25 of Set 13 | kearney
# Processing Record 26 of Set 13 | davila
# Processing Record 27 of Set 13 | kusk
# City not found. Skipping...
# Processing Record 28 of Set 13 | cienfuegos
# Processing Record 29 of Set 13 | adand
# Processing Record 30 of Set 13 | tommot
# Processing Record 31 of Set 13 | fare
# Processing Record 32 of Set 13 | hudson bay
# Processing Record 33 of Set 13 | inirida
# Processing Record 34 of Set 13 | qaqortoq
# Processing Record 35 of Set 13 | opuwo
# Processing Record 36 of Set 13 | pozhva
# Processing Record 37 of Set 13 | okha
# Processing Record 38 of Set 13 | avondale
# Processing Record 39 of Set 13 | ise
# Processing Record 40 of Set 13 | stokmarknes
# Processing Record 41 of Set 13 | mount gambier
# Processing Record 42 of Set 13 | san policarpo
# Processing Record 43 of Set 13 | japura
# Processing Record 44 of Set 13 | west bay
# Processing Record 45 of Set 13 | hirara
# Processing Record 46 of Set 13 | nanakuli
# Processing Record 47 of Set 13 | umred
# Processing Record 48 of Set 13 | athens
# Processing Record 49 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 13 | yagoua
# Processing Record 1 of Set 14 | bredy
# Processing Record 2 of Set 14 | iisalmi
# Processing Record 3 of Set 14 | richards bay
# Processing Record 4 of Set 14 | kabarnet
# Processing Record 5 of Set 14 | hualmay
# Processing Record 6 of Set 14 | lokosovo
# Processing Record 7 of Set 14 | chifeng
# Processing Record 8 of Set 14 | bagdarin
# Processing Record 9 of Set 14 | nanga eboko
# Processing Record 10 of Set 14 | artyom
# Processing Record 11 of Set 14 | takoradi
# Processing Record 12 of Set 14 | lushoto
# Processing Record 13 of Set 14 | morgan city
# Processing Record 14 of Set 14 | bakel
# Processing Record 15 of Set 14 | laguna
# Processing Record 16 of Set 14 | pangai
# Processing Record 17 of Set 14 | laranjeiras do sul
# Processing Record 18 of Set 14 | olavarria
# Processing Record 19 of Set 14 | calabozo
# Processing Record 20 of Set 14 | barranca
# Processing Record 21 of Set 14 | surt
# Processing Record 22 of Set 14 | karasjok
# Processing Record 23 of Set 14 | georgiyevskoye
# Processing Record 24 of Set 14 | kushiro
# Processing Record 25 of Set 14 | anderson
# Processing Record 26 of Set 14 | tottori
# Processing Record 27 of Set 14 | maryville
# Processing Record 28 of Set 14 | ternate
# Processing Record 29 of Set 14 | valente
# Processing Record 30 of Set 14 | khorixas
# Processing Record 31 of Set 14 | sidney
# Processing Record 32 of Set 14 | bac can
# City not found. Skipping...
# Processing Record 33 of Set 14 | seidu
# Processing Record 34 of Set 14 | vao
# Processing Record 35 of Set 14 | sokol
# Processing Record 36 of Set 14 | tautira
# Processing Record 37 of Set 14 | tarragona
# Processing Record 38 of Set 14 | whitianga
# Processing Record 39 of Set 14 | urengoy
# Processing Record 40 of Set 14 | malindi
# Processing Record 41 of Set 14 | basco
# Processing Record 42 of Set 14 | gatesville
# Processing Record 43 of Set 14 | hanchuan
# Processing Record 44 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 45 of Set 14 | suluq
# Processing Record 46 of Set 14 | watsa
# Processing Record 47 of Set 14 | kangalassy
# Processing Record 48 of Set 14 | yenagoa
# Processing Record 49 of Set 14 | tanete
# Processing Record 50 of Set 14 | cavalcante
# Processing Record 1 of Set 15 | limbang
# Processing Record 2 of Set 15 | nyurba
# Processing Record 3 of Set 15 | hakui
# Processing Record 4 of Set 15 | port angeles
# Processing Record 5 of Set 15 | bandon
# Processing Record 6 of Set 15 | jutai
# Processing Record 7 of Set 15 | half moon bay
# Processing Record 8 of Set 15 | phangnga
# Processing Record 9 of Set 15 | esmeraldas
# Processing Record 10 of Set 15 | seredka
# Processing Record 11 of Set 15 | marsh harbour
# Processing Record 12 of Set 15 | ewa beach
# Processing Record 13 of Set 15 | kiunga
# Processing Record 14 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 15 of Set 15 | portsmouth
# Processing Record 16 of Set 15 | morlaix
# Processing Record 17 of Set 15 | sabang
# Processing Record 18 of Set 15 | gayny
# Processing Record 19 of Set 15 | puqi
# Processing Record 20 of Set 15 | sampit
# Processing Record 21 of Set 15 | puri
# Processing Record 22 of Set 15 | kidal
# Processing Record 23 of Set 15 | lazaro cardenas
# Processing Record 24 of Set 15 | nishihara
# Processing Record 25 of Set 15 | notre-dame-du-lac
# Processing Record 26 of Set 15 | horki
# Processing Record 27 of Set 15 | solsvik
# City not found. Skipping...
# Processing Record 28 of Set 15 | hare bay
# Processing Record 29 of Set 15 | zhigansk
# Processing Record 30 of Set 15 | surovatikha
# Processing Record 31 of Set 15 | kedgwick
# Processing Record 32 of Set 15 | pundaguitan
# Processing Record 33 of Set 15 | sao paulo de olivenca
# Processing Record 34 of Set 15 | evensk
# Processing Record 35 of Set 15 | kloulklubed
# Processing Record 36 of Set 15 | ucluelet
# Processing Record 37 of Set 15 | kavaratti
# Processing Record 38 of Set 15 | mayya
# Processing Record 39 of Set 15 | batsfjord
# Processing Record 40 of Set 15 | birin
# Processing Record 41 of Set 15 | seydi
# Processing Record 42 of Set 15 | myslenice
# Processing Record 43 of Set 15 | kem
# Processing Record 44 of Set 15 | yulara
# Processing Record 45 of Set 15 | pimenta bueno
# Processing Record 46 of Set 15 | lagos
# Processing Record 47 of Set 15 | sulangan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Ushuaia -54.8000  -68.3000     29.86        93         100       19.57
# 1  Tuktoyaktuk  69.4541 -133.0374     51.80        93         100        6.91
# 2        Vaini -21.2000 -175.2000     74.01        75           5        9.33
# 3       Albany  42.6001  -73.9662     88.68        64           8        1.01
# 4  Yellowknife  62.4560 -114.3525     63.12        55          20        5.99
# 5    Busselton -33.6500  115.3333     56.70        75          75       10.92
# 6     Thompson  55.7435  -97.8558     60.96        94         100        9.22
# 7       Olinda  -8.0089  -34.8553     73.13        94          75        9.22
# 8  Clyde River  70.4692  -68.5914     39.43        93         100       16.11
# 9     Karratha -20.7377  116.8463     71.42        82           1        7.47
#
#   Country Current Description
# 0      AR          heavy snow
# 1      CA     overcast clouds
# 2      TO           clear sky
# 3      US           clear sky
# 4      CA          few clouds
# 5      AU       broken clouds
# 6      CA     overcast clouds
# 7      BR       broken clouds
# 8      CA          light rain
# 9      AU           clear sky

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Ushuaia      AR -54.8000  -68.3000     29.86        93         100
# 1  Tuktoyaktuk      CA  69.4541 -133.0374     51.80        93         100
# 2        Vaini      TO -21.2000 -175.2000     74.01        75           5
# 3       Albany      US  42.6001  -73.9662     88.68        64           8
# 4  Yellowknife      CA  62.4560 -114.3525     63.12        55          20
# 5    Busselton      AU -33.6500  115.3333     56.70        75          75
# 6     Thompson      CA  55.7435  -97.8558     60.96        94         100
# 7       Olinda      BR  -8.0089  -34.8553     73.13        94          75
# 8  Clyde River      CA  70.4692  -68.5914     39.43        93         100
# 9     Karratha      AU -20.7377  116.8463     71.42        82           1
#
#    Wind Speed Current Description
# 0       19.57          heavy snow
# 1        6.91     overcast clouds
# 2        9.33           clear sky
# 3        1.01           clear sky
# 4        5.99          few clouds
# 5       10.92       broken clouds
# 6        9.22     overcast clouds
# 7        9.22       broken clouds
# 8       16.11          light rain
# 9        7.47           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
